# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

# %%
ls
# Out:
# cad_117_threshNoBin.png*  mmh.ipynb*      simple_midRight_10.png*
# gym_maze.egg-info/        nn_bruh.ipynb*  Untitled.ipynb*
# gym_teen/                 README.md*
# gym_teen.egg-info/        setup.py*

# %%
im117 = Image.open('cadaver_slice_117.png').convert('L')

# %%
im117.save('cadaver_slice_117_grey.png')

# %%
im117n = np.array(im117)

# %%
fig,ax = plt.subplots(figsize=(8,8))
plt.imshow(im117n)

# %%
404-60
# Out:
# 344

# %%
tmin = 10000
tmax = 0
tminidx = (0,0)
tmaxidx = (0,0)
for i in range(100,200):
    for j in range(100,200):
        #i = i+100
        #j = j+100
        print(i,j)
        ttpatch = im117n[i:i+60,:]
        tmean = np.mean(ttpatch[:,j:j+60])
        print(tmean)
        if tmean < tmin:
            tmin = tmean
            tminidx = (i,j)
        if tmean > tmax:
            tmax = tmean
            tmaxidx = (i,j)
# Out:
# 100 100
# 118.44055555555556
# 100 101
# 118.51527777777778
# 100 102
# 118.58611111111111
# 100 103
# 118.65333333333334
# 100 104
# 118.72444444444444
# 100 105
# 118.79194444444444
# 100 106
# 118.86527777777778
# 100 107
# 118.91722222222222
# 100 108
# 118.96583333333334
# 100 109
# 119.01083333333334
# 100 110
# 119.04916666666666
# 100 111
# 119.08611111111111
# 100 112
# 119.12638888888888
# 100 113
# 119.16388888888889
# 100 114
# 119.20138888888889
# 100 115
# 119.23472222222222
# 100 116
# 119.27
# 100 117
# 119.29722222222222
# 100 118
# 119.32055555555556
# 100 119
# 119.33916666666667
# 100 120
# 119.36166666666666
# 100 121
# 119.42388888888888
# 100 122
# 119.47055555555555
# 100 123
# 119.53972222222222
# 100 124
# 119.61083333333333
# 100 125
# 119.6825
# 100 126
# 119.75305555555556
# 100 127
# 119.83666666666667
# 100 128
# 119.92666666666666
# 100 129
# 119.99916666666667
# 100 130
# 120.03416666666666
# 100 131
# 120.04638888888888
# 100 132
# ...

# %%
tmax
# Out:
# 123.81444444444445

# %%
tmin = 10000
tmax = 0
tminidx = (0,0)
tmaxidx = (0,0)
for i in range(344):
    for j in range(344):
        #print(i,j)
        ttpatch = im117n[i:i+60,:]
        tmean = np.mean(ttpatch[:,j:j+60])
        #print()
        if tmean < tmin:
            tmin = tmean
            tminidx = (i,j)
        if tmean > tmax:
            tmax = tmean
            tmaxidx = (i,j)

# %%
tmin
# Out:
# 30.003333333333334

# %%
tmax
# Out:
# 131.98444444444445

# %%
tmaxidx
# Out:
# (151, 158)

# %%
tpatch = im117n[151:151+60,:].copy()

# %%
plt.imshow(tpatch)

# %%
plt.imshow(tpatch[:,158:158+60])

# %%
np.mean(tpatch[:,160:200])
# Out:
# 129.6725

# %%
print(220-160)
print(200-140)
# Out:
# 60
# 60
